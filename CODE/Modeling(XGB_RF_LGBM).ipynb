# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import scipy.stats as stats
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder

from sklearn.model_selection import StratifiedKFold
from sklearn.model_selection import cross_val_score
from sklearn.metrics import f1_score

from sklearn.model_selection import RandomizedSearchCV
import pickle

# %% [markdown]
# # 데이터 준비

# %%
path1='/content/drive/MyDrive/ML/train_seriesA.xlsx'
path2='/content/drive/MyDrive/ML/test_seriesA.xlsx'
train=pd.read_excel(path1)
test=pd.read_excel(path2)

# %%
y_train=train.loc[:,'seriesB']
y_test=test.loc[:,'seriesB']

# %%
#변수중요도에서 뽑은 변수들
col=['netProfit','Started','operatingProfit','mean_Traffic','seed','totalAssets',
     'news','liabilities','tech_rank','employer','Make_month','profit','totalCapital',
     'tech_cnt','Make_year','ceo_info', 'uni_기타','uni_sky', 'uni_해외', 'uni_과학기술',
      'major_경영', 'major_공학', 'major_IT','major_사회', 'major_예체능', 'major_자연', 'major_인문', 'major_의약', 'major_교육']

# %%
X_train=train.loc[:,col]
X_test=test.loc[:,col]

# %% [markdown]
# # 옵튜나

# %%
# !pip install optuna
# Out:
# Collecting optuna
#   Downloading optuna-3.5.0-py3-none-any.whl (413 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 413.4/413.4 kB 4.4 MB/s eta 0:00:00
# Collecting alembic>=1.5.0 (from optuna)
#   Downloading alembic-1.13.1-py3-none-any.whl (233 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 233.4/233.4 kB 7.1 MB/s eta 0:00:00
# Collecting colorlog (from optuna)
#   Downloading colorlog-6.8.2-py3-none-any.whl (11 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from optuna) (1.23.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from optuna) (23.2)
# Requirement already satisfied: sqlalchemy>=1.3.0 in /usr/local/lib/python3.10/dist-packages (from optuna) (2.0.24)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from optuna) (4.66.1)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.10/dist-packages (from optuna) (6.0.1)
# Collecting Mako (from alembic>=1.5.0->optuna)
#   Downloading Mako-1.3.2-py3-none-any.whl (78 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.7/78.7 kB 10.1 MB/s eta 0:00:00
# Requirement already satisfied: typing-extensions>=4 in /usr/local/lib/python3.10/dist-packages (from alembic>=1.5.0->optuna) (4.5.0)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.10/dist-packages (from sqlalchemy>=1.3.0->optuna) (3.0.3)
# Requirement already satisfied: MarkupSafe>=0.9.2 in /usr/local/lib/python3.10/dist-packages (from Mako->alembic>=1.5.0->optuna) (2.1.4)
# Installing collected packages: Mako, colorlog, alembic, optuna
# Successfully installed Mako-1.3.2 alembic-1.13.1 colorlog-6.8.2 optuna-3.5.0

# %%
import optuna

# %%
str_kfold = StratifiedKFold(n_splits=5, random_state=777, shuffle=True)

# %% [markdown]
# # XGBoost

# %%
from xgboost import XGBClassifier

# %%
def xgb_objective(trail):
    params = {
        "n_estimators" : trail.suggest_int("n_estimators", 3,1000),
        "criterion": trail.suggest_categorical("criterion", ["gini", "entropy","log_loss"]),
        "max_depth":trail.suggest_int("max_depth", 1, 100),
        "min_samples_leaf":trail.suggest_int("min_samples_leaf", 1, 20),
        "max_features": trail.suggest_int("max_features", 1, X_train.shape[1]),
        "max_leaf_nodes":trail.suggest_int("max_leaf_nodes", 2, 20)
    }
    xgb=XGBClassifier(n_jobs=-1,random_state=777,**params)
    xgb.fit(X_train,y_train)
    scores=cross_val_score(xgb,X_train,y_train,cv=str_kfold,
                         scoring='f1')
    f1_mean=scores.mean()
    return f1_mean

# %%
xgb_study=optuna.create_study(direction='maximize')
xgb_study.optimize(xgb_objective,n_trials=50,n_jobs=-1)
# Out:
# [I 2024-02-06 05:15:53,439] A new study created in memory with name: no-name-b6514e9b-ab77-435e-96e2-f732950b6664
# [I 2024-02-06 05:15:55,433] Trial 1 finished with value: 0.6413174092893319 and parameters: {'n_estimators': 76, 'criterion': 'log_loss', 'max_depth': 28, 'min_samples_leaf': 16, 'max_features': 27, 'max_leaf_nodes': 7}. Best is trial 1 with value: 0.6413174092893319.
# [I 2024-02-06 05:16:00,296] Trial 0 finished with value: 0.649952743453957 and parameters: {'n_estimators': 492, 'criterion': 'log_loss', 'max_depth': 100, 'min_samples_leaf': 20, 'max_features': 11, 'max_leaf_nodes': 20}. Best is trial 0 with value: 0.649952743453957.
# [I 2024-02-06 05:16:04,608] Trial 2 finished with value: 0.6392554968766417 and parameters: {'n_estimators': 563, 'criterion': 'gini', 'max_depth': 12, 'min_samples_leaf': 19, 'max_features': 15, 'max_leaf_nodes': 4}. Best is trial 0 with value: 0.649952743453957.
# [I 2024-02-06 05:16:05,250] Trial 3 finished with value: 0.6458736533305878 and parameters: {'n_estimators': 178, 'criterion': 'entropy', 'max_depth': 61, 'min_samples_leaf': 17, 'max_features': 12, 'max_leaf_nodes': 12}. Best is trial 0 with value: 0.649952743453957.
# [I 2024-02-06 05:16:12,998] Trial 4 finished with value: 0.6427560025151503 and parameters: {'n_estimators': 802, 'criterion': 'log_loss', 'max_depth': 44, 'min_samples_leaf': 6, 'max_features': 27, 'max_leaf_nodes': 17}. Best is trial 0 with value: 0.649952743453957.
# [I 2024-02-06 05:16:14,380] Trial 5 finished with value: 0.6380805292569998 and parameters: {'n_estimators': 899, 'criterion': 'gini', 'max_depth': 89, 'min_samples_leaf': 17, 'max_features': 26, 'max_leaf_nodes': 7}. Best is trial 0 with value: 0.649952743453957.
# [I 2024-02-06 05:16:17,816] Trial 7 finished with value: 0.6528637898093935 and parameters: {'n_estimators': 60, 'criterion': 'gini', 'max_depth': 16, 'min_samples_leaf': 4, 'max_features': 2, 'max_leaf_nodes': 14}. Best is trial 7 with value: 0.6528637898093935.
# [I 2024-02-06 05:16:20,753] Trial 6 finished with value: 0.6472114527629234 and parameters: {'n_estimators': 506, 'criterion': 'entropy', 'max_depth': 59, 'min_samples_leaf': 19, 'max_features': 14, 'max_leaf_nodes': 7}. Best is trial 7 with value: 0.6528637898093935.
# [I 2024-02-06 05:16:23,933] Trial 8 finished with value: 0.6472114527629234 and parameters: {'n_estimators': 564, 'criterion': 'entropy', 'max_depth': 42, 'min_samples_leaf': 9, 'max_features': 25, 'max_leaf_nodes': 19}. Best is trial 7 with value: 0.6528637898093935.
# [I 2024-02-06 05:16:32,760] Trial 9 finished with value: 0.6352849555819853 and parameters: {'n_estimators': 977, 'criterion': 'log_loss', 'max_depth': 56, 'min_samples_leaf': 9, 'max_features': 20, 'max_leaf_nodes': 3}. Best is trial 7 with value: 0.6528637898093935.
# [I 2024-02-06 05:16:34,347] Trial 10 finished with value: 0.6361615423537093 and parameters: {'n_estimators': 764, 'criterion': 'entropy', 'max_depth': 6, 'min_samples_leaf': 11, 'max_features': 18, 'max_leaf_nodes': 11}. Best is trial 7 with value: 0.6528637898093935.
# [I 2024-02-06 05:16:36,116] Trial 11 finished with value: 0.6432133725237174 and parameters: {'n_estimators': 265, 'criterion': 'gini', 'max_depth': 3, 'min_samples_leaf': 1, 'max_features': 1, 'max_leaf_nodes': 13}. Best is trial 7 with value: 0.6528637898093935.
# [I 2024-02-06 05:16:38,636] Trial 12 finished with value: 0.6563885652076392 and parameters: {'n_estimators': 266, 'criterion': 'gini', 'max_depth': 97, 'min_samples_leaf': 2, 'max_features': 4, 'max_leaf_nodes': 16}. Best is trial 12 with value: 0.6563885652076392.
# [I 2024-02-06 05:16:40,013] Trial 14 finished with value: 0.6531061656039185 and parameters: {'n_estimators': 23, 'criterion': 'gini', 'max_depth': 76, 'min_samples_leaf': 1, 'max_features': 1, 'max_leaf_nodes': 16}. Best is trial 12 with value: 0.6563885652076392.
# [I 2024-02-06 05:16:41,377] Trial 13 finished with value: 0.652641317016317 and parameters: {'n_estimators': 359, 'criterion': 'log_loss', 'max_depth': 96, 'min_samples_leaf': 1, 'max_features': 5, 'max_leaf_nodes': 16}. Best is trial 12 with value: 0.6563885652076392.
# [I 2024-02-06 05:16:41,866] Trial 16 finished with value: 0.5552868567490113 and parameters: {'n_estimators': 3, 'criterion': 'gini', 'max_depth': 78, 'min_samples_leaf': 4, 'max_features': 7, 'max_leaf_nodes': 16}. Best is trial 12 with value: 0.6563885652076392.
# [I 2024-02-06 05:16:50,567] Trial 15 finished with value: 0.6540082031942497 and parameters: {'n_estimators': 323, 'criterion': 'gini', 'max_depth': 76, 'min_samples_leaf': 1, 'max_features': 6, 'max_leaf_nodes': 16}. Best is trial 12 with value: 0.6563885652076392.
# [I 2024-02-06 05:16:51,162] Trial 17 finished with value: 0.6458736533305878 and parameters: {'n_estimators': 188, 'criterion': 'gini', 'max_depth': 76, 'min_samples_leaf': 4, 'max_features': 7, 'max_leaf_nodes': 18}. Best is trial 12 with value: 0.6563885652076392.
# [I 2024-02-06 05:17:01,696] Trial 18 finished with value: 0.649952743453957 and parameters: {'n_estimators': 341, 'criterion': 'gini', 'max_depth': 78, 'min_samples_leaf': 5, 'max_features': 8, 'max_leaf_nodes': 10}. Best is trial 12 with value: 0.6563885652076392.
# [I 2024-02-06 05:17:03,196] Trial 19 finished with value: 0.6487833376385335 and parameters: {'n_estimators': 389, 'criterion': 'gini', 'max_depth': 86, 'min_samples_leaf': 13, 'max_features': 5, 'max_leaf_nodes': 9}. Best is trial 12 with value: 0.6563885652076392.
# [I 2024-02-06 05:17:09,256] Trial 20 finished with value: 0.649952743453957 and parameters: {'n_estimators': 350, 'criterion': 'gini', 'max_depth': 90, 'min_samples_leaf': 13, 'max_features': 4, 'max_leaf_nodes': 14}. Best is trial 12 with value: 0.6563885652076392.
# [I 2024-02-06 05:17:14,574] Trial 22 finished with value: 0.6446967755181959 and parameters: {'n_estimators': 158, 'criterion': 'gini', 'max_depth': 68, 'min_samples_leaf': 2, 'max_features': 2, 'max_leaf_nodes': 15}. Best is trial 12 with value: 0.6563885652076392.
# [I 2024-02-06 05:17:15,016] Trial 21 finished with value: 0.6479104206193113 and parameters: {'n_estimators': 670, 'criterion': 'gini', 'max_depth': 67, 'min_samples_leaf': 7, 'max_features': 4, 'max_leaf_nodes': 14}. Best is trial 12 with value: 0.6563885652076392.
# [I 2024-02-06 05:17:18,203] Trial 24 finished with value: 0.6484743859313203 and parameters: {'n_estimators': 206, 'criterion': 'gini', 'max_depth': 81, 'min_samples_leaf': 2, 'max_features': 9, 'max_leaf_nodes': 18}. Best is trial 12 with value: 0.6563885652076392.
# [I 2024-02-06 05:17:18,292] Trial 23 finished with value: 0.6531526806526806 and parameters: {'n_estimators': 244, 'criterion': 'gini', 'max_depth': 70, 'min_samples_leaf': 7, 'max_features': 10, 'max_leaf_nodes': 17}. Best is trial 12 with value: 0.6563885652076392.
# [I 2024-02-06 05:17:22,823] Trial 25 finished with value: 0.6550985792846258 and parameters: {'n_estimators': 276, 'criterion': 'gini', 'max_depth': 72, 'min_samples_leaf': 2, 'max_features': 1, 'max_leaf_nodes': 20}. Best is trial 12 with value: 0.6563885652076392.
# [I 2024-02-06 05:17:23,363] Trial 26 finished with value: 0.656293500867897 and parameters: {'n_estimators': 287, 'criterion': 'gini', 'max_depth': 69, 'min_samples_leaf': 7, 'max_features': 10, 'max_leaf_nodes': 19}. Best is trial 12 with value: 0.6563885652076392.
# [I 2024-02-06 05:17:33,162] Trial 28 finished with value: 0.649952743453957 and parameters: {'n_estimators': 445, 'criterion': 'gini', 'max_depth': 49, 'min_samples_leaf': 3, 'max_features': 13, 'max_leaf_nodes': 20}. Best is trial 12 with value: 0.6563885652076392.
# [I 2024-02-06 05:17:33,166] Trial 27 finished with value: 0.649952743453957 and parameters: {'n_estimators': 449, 'criterion': 'gini', 'max_depth': 50, 'min_samples_leaf': 3, 'max_features': 6, 'max_leaf_nodes': 20}. Best is trial 12 with value: 0.6563885652076392.
# [I 2024-02-06 05:17:36,836] Trial 30 finished with value: 0.646513125392041 and parameters: {'n_estimators': 126, 'criterion': 'entropy', 'max_depth': 34, 'min_samples_leaf': 8, 'max_features': 11, 'max_leaf_nodes': 19}. Best is trial 12 with value: 0.6563885652076392.
# [I 2024-02-06 05:17:37,291] Trial 29 finished with value: 0.6377921724245253 and parameters: {'n_estimators': 137, 'criterion': 'entropy', 'max_depth': 98, 'min_samples_leaf': 6, 'max_features': 17, 'max_leaf_nodes': 19}. Best is trial 12 with value: 0.6563885652076392.
# [I 2024-02-06 05:17:45,606] Trial 31 finished with value: 0.652738697278726 and parameters: {'n_estimators': 274, 'criterion': 'log_loss', 'max_depth': 100, 'min_samples_leaf': 6, 'max_features': 3, 'max_leaf_nodes': 20}. Best is trial 12 with value: 0.6563885652076392.
# [I 2024-02-06 05:17:46,782] Trial 32 finished with value: 0.652571753393314 and parameters: {'n_estimators': 292, 'criterion': 'gini', 'max_depth': 70, 'min_samples_leaf': 2, 'max_features': 3, 'max_leaf_nodes': 18}. Best is trial 12 with value: 0.6563885652076392.
# [I 2024-02-06 05:17:54,017] Trial 33 finished with value: 0.6515494346215736 and parameters: {'n_estimators': 309, 'criterion': 'gini', 'max_depth': 70, 'min_samples_leaf': 3, 'max_features': 9, 'max_leaf_nodes': 18}. Best is trial 12 with value: 0.6563885652076392.
# [I 2024-02-06 05:17:57,238] Trial 34 finished with value: 0.6487833376385335 and parameters: {'n_estimators': 414, 'criterion': 'gini', 'max_depth': 84, 'min_samples_leaf': 3, 'max_features': 9, 'max_leaf_nodes': 17}. Best is trial 12 with value: 0.6563885652076392.
# [I 2024-02-06 05:18:01,794] Trial 36 finished with value: 0.6543476022359517 and parameters: {'n_estimators': 239, 'criterion': 'gini', 'max_depth': 63, 'min_samples_leaf': 5, 'max_features': 7, 'max_leaf_nodes': 15}. Best is trial 12 with value: 0.6563885652076392.
# [I 2024-02-06 05:18:02,312] Trial 35 finished with value: 0.649952743453957 and parameters: {'n_estimators': 433, 'criterion': 'gini', 'max_depth': 84, 'min_samples_leaf': 11, 'max_features': 6, 'max_leaf_nodes': 17}. Best is trial 12 with value: 0.6563885652076392.
# [I 2024-02-06 05:18:08,079] Trial 38 finished with value: 0.6484743859313203 and parameters: {'n_estimators': 215, 'criterion': 'log_loss', 'max_depth': 63, 'min_samples_leaf': 5, 'max_features': 12, 'max_leaf_nodes': 13}. Best is trial 12 with value: 0.6563885652076392.
# [I 2024-02-06 05:18:14,556] Trial 39 finished with value: 0.642350873856261 and parameters: {'n_estimators': 91, 'criterion': 'gini', 'max_depth': 55, 'min_samples_leaf': 5, 'max_features': 16, 'max_leaf_nodes': 15}. Best is trial 12 with value: 0.6563885652076392.
# [I 2024-02-06 05:18:14,866] Trial 37 finished with value: 0.6472114527629234 and parameters: {'n_estimators': 514, 'criterion': 'gini', 'max_depth': 63, 'min_samples_leaf': 5, 'max_features': 12, 'max_leaf_nodes': 15}. Best is trial 12 with value: 0.6563885652076392.
# [I 2024-02-06 05:18:26,564] Trial 40 finished with value: 0.6472114527629234 and parameters: {'n_estimators': 500, 'criterion': 'gini', 'max_depth': 92, 'min_samples_leaf': 9, 'max_features': 29, 'max_leaf_nodes': 5}. Best is trial 12 with value: 0.6563885652076392.
# [I 2024-02-06 05:18:27,258] Trial 41 finished with value: 0.6504045995906461 and parameters: {'n_estimators': 612, 'criterion': 'gini', 'max_depth': 93, 'min_samples_leaf': 9, 'max_features': 22, 'max_leaf_nodes': 12}. Best is trial 12 with value: 0.6563885652076392.
# [I 2024-02-06 05:18:32,425] Trial 43 finished with value: 0.6531526806526806 and parameters: {'n_estimators': 235, 'criterion': 'gini', 'max_depth': 57, 'min_samples_leaf': 2, 'max_features': 7, 'max_leaf_nodes': 19}. Best is trial 12 with value: 0.6563885652076392.
# [I 2024-02-06 05:18:32,847] Trial 42 finished with value: 0.6540082031942497 and parameters: {'n_estimators': 322, 'criterion': 'gini', 'max_depth': 73, 'min_samples_leaf': 1, 'max_features': 5, 'max_leaf_nodes': 19}. Best is trial 12 with value: 0.6563885652076392.
# [I 2024-02-06 05:18:35,212] Trial 45 finished with value: 0.6409513915899752 and parameters: {'n_estimators': 80, 'criterion': 'log_loss', 'max_depth': 43, 'min_samples_leaf': 4, 'max_features': 3, 'max_leaf_nodes': 16}. Best is trial 12 with value: 0.6563885652076392.
# [I 2024-02-06 05:18:40,480] Trial 44 finished with value: 0.6515512007372473 and parameters: {'n_estimators': 343, 'criterion': 'gini', 'max_depth': 74, 'min_samples_leaf': 1, 'max_features': 4, 'max_leaf_nodes': 16}. Best is trial 12 with value: 0.6563885652076392.
# [I 2024-02-06 05:18:43,108] Trial 46 finished with value: 0.649952743453957 and parameters: {'n_estimators': 384, 'criterion': 'entropy', 'max_depth': 63, 'min_samples_leaf': 7, 'max_features': 10, 'max_leaf_nodes': 13}. Best is trial 12 with value: 0.6563885652076392.
# [I 2024-02-06 05:18:45,711] Trial 47 finished with value: 0.6487833376385335 and parameters: {'n_estimators': 393, 'criterion': 'entropy', 'max_depth': 63, 'min_samples_leaf': 7, 'max_features': 2, 'max_leaf_nodes': 18}. Best is trial 12 with value: 0.6563885652076392.
# [I 2024-02-06 05:18:47,617] Trial 48 finished with value: 0.6539081030941496 and parameters: {'n_estimators': 279, 'criterion': 'gini', 'max_depth': 37, 'min_samples_leaf': 3, 'max_features': 1, 'max_leaf_nodes': 20}. Best is trial 12 with value: 0.6563885652076392.
# [I 2024-02-06 05:18:57,197] Trial 49 finished with value: 0.6575790413981154 and parameters: {'n_estimators': 272, 'criterion': 'gini', 'max_depth': 54, 'min_samples_leaf': 3, 'max_features': 1, 'max_leaf_nodes': 20}. Best is trial 49 with value: 0.6575790413981154.

# %%
xgb_study.best_params
# Out:
# {'n_estimators': 272,
#  'criterion': 'gini',
#  'max_depth': 54,
#  'min_samples_leaf': 3,
#  'max_features': 1,
#  'max_leaf_nodes': 20}

# %%
#모델만들기
opt_xgb=XGBClassifier(n_jobs=-1, random_state=777,
                               **xgb_study.best_params)
opt_xgb.fit(X_train,y_train)
# Out:
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:160: UserWarning: [05:20:04] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "criterion", "max_features", "max_leaf_nodes", "min_samples_leaf" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, criterion='gini', device=None,
#               early_stopping_rounds=None, enable_categorical=False,
#               eval_metric=None, feature_types=None, gamma=None,
#               grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=54, max_features=1,
#               max_leaf_nodes=20, max_leaves=None, min_child_weight=None,
#               min_samples_leaf=3, missing=nan, monotone_constraints=None,
#               multi_strategy=None, ...)

# %%
#정확도 체크
opt_xgb_ypred=opt_xgb.predict(X_test)
opt_xgb_f1=f1_score(y_test,opt_xgb_ypred)
opt_xgb_f1
# Out:
# 0.676470588235294

# %%
#모델 저장
filename = "xgb_f1_67.pkl"
pickle.dump(opt_xgb, open( filename, "wb") )

# %%
#잘 저장되었는지 확인
new_model = pickle.load( open( "/content/xgb_f1_67.pkl", "rb"))
(new_model.predict(X_test) != opt_xgb.predict(X_test)).sum()
# Out:
# 0

# %% [markdown]
# # Random Forest

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
def rf_objective(trail):
    params = {
        "n_estimators" : trail.suggest_int("n_estimators", 3,1000),
        "criterion": trail.suggest_categorical("criterion", ["gini", "entropy","log_loss"]),
        "max_depth":trail.suggest_int("max_depth", 1, 100),
        "min_samples_leaf":trail.suggest_int("min_samples_leaf", 1, 20),
        "max_features": trail.suggest_int("max_features", 1, X_train.shape[1]),
        "max_leaf_nodes":trail.suggest_int("max_leaf_nodes", 2, 20)
    }
    rf=RandomForestClassifier(n_jobs=-1,random_state=777,**params)
    rf.fit(X_train,y_train)
    scores=cross_val_score(rf,X_train,y_train,cv=str_kfold,
                         scoring='f1')
    f1_mean=scores.mean()
    return f1_mean

# %%
rf_study=optuna.create_study(direction='maximize')
rf_study.optimize(rf_objective,n_trials=50,n_jobs=-1)
# Out:
# [I 2024-02-06 05:20:38,875] A new study created in memory with name: no-name-1b964c39-f2e3-476c-8b53-b09e6e9572af
# [I 2024-02-06 05:20:50,692] Trial 0 finished with value: 0.5893845869071086 and parameters: {'n_estimators': 282, 'criterion': 'gini', 'max_depth': 53, 'min_samples_leaf': 3, 'max_features': 2, 'max_leaf_nodes': 17}. Best is trial 0 with value: 0.5893845869071086.
# [I 2024-02-06 05:20:57,289] Trial 2 finished with value: 0.6566227937724542 and parameters: {'n_estimators': 102, 'criterion': 'entropy', 'max_depth': 75, 'min_samples_leaf': 18, 'max_features': 4, 'max_leaf_nodes': 14}. Best is trial 2 with value: 0.6566227937724542.
# [I 2024-02-06 05:21:24,599] Trial 1 finished with value: 0.6680482859415339 and parameters: {'n_estimators': 651, 'criterion': 'log_loss', 'max_depth': 93, 'min_samples_leaf': 3, 'max_features': 9, 'max_leaf_nodes': 17}. Best is trial 1 with value: 0.6680482859415339.
# [I 2024-02-06 05:21:36,237] Trial 4 finished with value: 0.6598490283291086 and parameters: {'n_estimators': 282, 'criterion': 'entropy', 'max_depth': 98, 'min_samples_leaf': 17, 'max_features': 6, 'max_leaf_nodes': 10}. Best is trial 1 with value: 0.6680482859415339.
# [I 2024-02-06 05:22:11,670] Trial 3 finished with value: 0.6631895172361558 and parameters: {'n_estimators': 904, 'criterion': 'log_loss', 'max_depth': 90, 'min_samples_leaf': 5, 'max_features': 21, 'max_leaf_nodes': 16}. Best is trial 1 with value: 0.6680482859415339.
# [I 2024-02-06 05:22:14,648] Trial 5 finished with value: 0.6456573293398874 and parameters: {'n_estimators': 914, 'criterion': 'gini', 'max_depth': 1, 'min_samples_leaf': 12, 'max_features': 28, 'max_leaf_nodes': 16}. Best is trial 1 with value: 0.6680482859415339.
# [I 2024-02-06 05:22:37,146] Trial 7 finished with value: 0.659342412323469 and parameters: {'n_estimators': 335, 'criterion': 'gini', 'max_depth': 5, 'min_samples_leaf': 5, 'max_features': 17, 'max_leaf_nodes': 6}. Best is trial 1 with value: 0.6680482859415339.
# [I 2024-02-06 05:22:45,709] Trial 8 finished with value: 0.5691839392001226 and parameters: {'n_estimators': 217, 'criterion': 'log_loss', 'max_depth': 47, 'min_samples_leaf': 1, 'max_features': 3, 'max_leaf_nodes': 6}. Best is trial 1 with value: 0.6680482859415339.
# [I 2024-02-06 05:23:03,110] Trial 9 finished with value: 0.6531129521285386 and parameters: {'n_estimators': 192, 'criterion': 'gini', 'max_depth': 62, 'min_samples_leaf': 9, 'max_features': 19, 'max_leaf_nodes': 7}. Best is trial 1 with value: 0.6680482859415339.
# [I 2024-02-06 05:23:03,275] Trial 6 finished with value: 0.6493763835212099 and parameters: {'n_estimators': 758, 'criterion': 'gini', 'max_depth': 91, 'min_samples_leaf': 10, 'max_features': 13, 'max_leaf_nodes': 17}. Best is trial 1 with value: 0.6680482859415339.
# [I 2024-02-06 05:23:46,638] Trial 11 finished with value: 0.6582531888091843 and parameters: {'n_estimators': 588, 'criterion': 'log_loss', 'max_depth': 30, 'min_samples_leaf': 13, 'max_features': 10, 'max_leaf_nodes': 20}. Best is trial 1 with value: 0.6680482859415339.
# [I 2024-02-06 05:23:50,200] Trial 10 finished with value: 0.6533904937470939 and parameters: {'n_estimators': 719, 'criterion': 'entropy', 'max_depth': 78, 'min_samples_leaf': 12, 'max_features': 7, 'max_leaf_nodes': 17}. Best is trial 1 with value: 0.6680482859415339.
# [I 2024-02-06 05:25:13,098] Trial 12 finished with value: 0.6660231097038138 and parameters: {'n_estimators': 971, 'criterion': 'log_loss', 'max_depth': 80, 'min_samples_leaf': 6, 'max_features': 24, 'max_leaf_nodes': 12}. Best is trial 1 with value: 0.6680482859415339.
# [I 2024-02-06 05:25:19,695] Trial 13 finished with value: 0.6624317077258254 and parameters: {'n_estimators': 994, 'criterion': 'log_loss', 'max_depth': 83, 'min_samples_leaf': 6, 'max_features': 23, 'max_leaf_nodes': 12}. Best is trial 1 with value: 0.6680482859415339.
# [I 2024-02-06 05:25:58,452] Trial 14 finished with value: 0.6625207307907676 and parameters: {'n_estimators': 489, 'criterion': 'log_loss', 'max_depth': 73, 'min_samples_leaf': 7, 'max_features': 25, 'max_leaf_nodes': 11}. Best is trial 1 with value: 0.6680482859415339.
# [I 2024-02-06 05:26:04,215] Trial 15 finished with value: 0.6543332953493447 and parameters: {'n_estimators': 535, 'criterion': 'log_loss', 'max_depth': 66, 'min_samples_leaf': 7, 'max_features': 27, 'max_leaf_nodes': 3}. Best is trial 1 with value: 0.6680482859415339.
# [I 2024-02-06 05:26:41,751] Trial 16 finished with value: 0.6508341345175561 and parameters: {'n_estimators': 710, 'criterion': 'log_loss', 'max_depth': 62, 'min_samples_leaf': 3, 'max_features': 13, 'max_leaf_nodes': 3}. Best is trial 1 with value: 0.6680482859415339.
# [I 2024-02-06 05:27:04,221] Trial 17 finished with value: 0.663171815345526 and parameters: {'n_estimators': 742, 'criterion': 'log_loss', 'max_depth': 41, 'min_samples_leaf': 1, 'max_features': 13, 'max_leaf_nodes': 20}. Best is trial 1 with value: 0.6680482859415339.
# [I 2024-02-06 05:27:25,302] Trial 19 finished with value: 0.6582929101249981 and parameters: {'n_estimators': 401, 'criterion': 'log_loss', 'max_depth': 98, 'min_samples_leaf': 15, 'max_features': 10, 'max_leaf_nodes': 13}. Best is trial 1 with value: 0.6680482859415339.
# [I 2024-02-06 05:27:35,025] Trial 18 finished with value: 0.67030755249438 and parameters: {'n_estimators': 817, 'criterion': 'log_loss', 'max_depth': 97, 'min_samples_leaf': 1, 'max_features': 10, 'max_leaf_nodes': 20}. Best is trial 18 with value: 0.67030755249438.
# [I 2024-02-06 05:28:17,833] Trial 20 finished with value: 0.6720870449634748 and parameters: {'n_estimators': 856, 'criterion': 'log_loss', 'max_depth': 29, 'min_samples_leaf': 3, 'max_features': 17, 'max_leaf_nodes': 9}. Best is trial 20 with value: 0.6720870449634748.
# [I 2024-02-06 05:28:20,130] Trial 21 finished with value: 0.6633442834286327 and parameters: {'n_estimators': 830, 'criterion': 'entropy', 'max_depth': 18, 'min_samples_leaf': 3, 'max_features': 9, 'max_leaf_nodes': 20}. Best is trial 20 with value: 0.6720870449634748.
# [I 2024-02-06 05:29:07,350] Trial 23 finished with value: 0.6634202028659497 and parameters: {'n_estimators': 618, 'criterion': 'log_loss', 'max_depth': 31, 'min_samples_leaf': 1, 'max_features': 16, 'max_leaf_nodes': 8}. Best is trial 20 with value: 0.6720870449634748.
# [I 2024-02-06 05:29:10,972] Trial 22 finished with value: 0.6646000100794648 and parameters: {'n_estimators': 819, 'criterion': 'log_loss', 'max_depth': 23, 'min_samples_leaf': 3, 'max_features': 9, 'max_leaf_nodes': 19}. Best is trial 20 with value: 0.6720870449634748.
# [I 2024-02-06 05:29:49,595] Trial 25 finished with value: 0.6675681155822374 and parameters: {'n_estimators': 630, 'criterion': 'log_loss', 'max_depth': 90, 'min_samples_leaf': 4, 'max_features': 19, 'max_leaf_nodes': 9}. Best is trial 20 with value: 0.6720870449634748.
# [I 2024-02-06 05:29:56,088] Trial 24 finished with value: 0.672815250231413 and parameters: {'n_estimators': 830, 'criterion': 'log_loss', 'max_depth': 16, 'min_samples_leaf': 3, 'max_features': 14, 'max_leaf_nodes': 18}. Best is trial 24 with value: 0.672815250231413.
# [I 2024-02-06 05:30:38,614] Trial 26 finished with value: 0.6662973600076085 and parameters: {'n_estimators': 835, 'criterion': 'log_loss', 'max_depth': 10, 'min_samples_leaf': 8, 'max_features': 14, 'max_leaf_nodes': 14}. Best is trial 24 with value: 0.672815250231413.
# [I 2024-02-06 05:30:46,565] Trial 27 finished with value: 0.6741756532421583 and parameters: {'n_estimators': 847, 'criterion': 'log_loss', 'max_depth': 13, 'min_samples_leaf': 1, 'max_features': 14, 'max_leaf_nodes': 14}. Best is trial 27 with value: 0.6741756532421583.
# [I 2024-02-06 05:31:34,926] Trial 28 finished with value: 0.6649748452040278 and parameters: {'n_estimators': 880, 'criterion': 'log_loss', 'max_depth': 14, 'min_samples_leaf': 1, 'max_features': 17, 'max_leaf_nodes': 19}. Best is trial 27 with value: 0.6741756532421583.
# [I 2024-02-06 05:31:39,237] Trial 29 finished with value: 0.6601018552640322 and parameters: {'n_estimators': 903, 'criterion': 'entropy', 'max_depth': 15, 'min_samples_leaf': 20, 'max_features': 18, 'max_leaf_nodes': 15}. Best is trial 27 with value: 0.6741756532421583.
# [I 2024-02-06 05:32:02,906] Trial 31 finished with value: 0.6564554352279209 and parameters: {'n_estimators': 474, 'criterion': 'gini', 'max_depth': 28, 'min_samples_leaf': 5, 'max_features': 15, 'max_leaf_nodes': 10}. Best is trial 27 with value: 0.6741756532421583.
# [I 2024-02-06 05:32:34,136] Trial 30 finished with value: 0.6663214867909748 and parameters: {'n_estimators': 941, 'criterion': 'entropy', 'max_depth': 34, 'min_samples_leaf': 5, 'max_features': 19, 'max_leaf_nodes': 15}. Best is trial 27 with value: 0.6741756532421583.
# [I 2024-02-06 05:32:46,774] Trial 32 finished with value: 0.6701392297283868 and parameters: {'n_estimators': 787, 'criterion': 'log_loss', 'max_depth': 36, 'min_samples_leaf': 2, 'max_features': 12, 'max_leaf_nodes': 18}. Best is trial 27 with value: 0.6741756532421583.
# [I 2024-02-06 05:33:12,040] Trial 34 finished with value: 0.27124291643581294 and parameters: {'n_estimators': 698, 'criterion': 'log_loss', 'max_depth': 22, 'min_samples_leaf': 2, 'max_features': 1, 'max_leaf_nodes': 13}. Best is trial 27 with value: 0.6741756532421583.
# [I 2024-02-06 05:33:16,742] Trial 33 finished with value: 0.6692828907008189 and parameters: {'n_estimators': 785, 'criterion': 'log_loss', 'max_depth': 22, 'min_samples_leaf': 2, 'max_features': 11, 'max_leaf_nodes': 18}. Best is trial 27 with value: 0.6741756532421583.
# [I 2024-02-06 05:33:57,337] Trial 35 finished with value: 0.6719619821393745 and parameters: {'n_estimators': 864, 'criterion': 'log_loss', 'max_depth': 50, 'min_samples_leaf': 4, 'max_features': 11, 'max_leaf_nodes': 18}. Best is trial 27 with value: 0.6741756532421583.
# [I 2024-02-06 05:34:03,586] Trial 36 finished with value: 0.6604558717300322 and parameters: {'n_estimators': 670, 'criterion': 'log_loss', 'max_depth': 50, 'min_samples_leaf': 4, 'max_features': 21, 'max_leaf_nodes': 18}. Best is trial 27 with value: 0.6741756532421583.
# [I 2024-02-06 05:34:37,958] Trial 37 finished with value: 0.6649826284386716 and parameters: {'n_estimators': 880, 'criterion': 'log_loss', 'max_depth': 51, 'min_samples_leaf': 4, 'max_features': 7, 'max_leaf_nodes': 15}. Best is trial 27 with value: 0.6741756532421583.
# [I 2024-02-06 05:34:44,717] Trial 38 finished with value: 0.6649826284386716 and parameters: {'n_estimators': 876, 'criterion': 'log_loss', 'max_depth': 41, 'min_samples_leaf': 4, 'max_features': 7, 'max_leaf_nodes': 16}. Best is trial 27 with value: 0.6741756532421583.
# [I 2024-02-06 05:35:27,313] Trial 40 finished with value: 0.6560123375747761 and parameters: {'n_estimators': 927, 'criterion': 'gini', 'max_depth': 7, 'min_samples_leaf': 6, 'max_features': 15, 'max_leaf_nodes': 5}. Best is trial 27 with value: 0.6741756532421583.
# [I 2024-02-06 05:35:28,724] Trial 39 finished with value: 0.6643289999898669 and parameters: {'n_estimators': 866, 'criterion': 'log_loss', 'max_depth': 9, 'min_samples_leaf': 7, 'max_features': 15, 'max_leaf_nodes': 16}. Best is trial 27 with value: 0.6741756532421583.
# [I 2024-02-06 05:35:57,624] Trial 42 finished with value: 0.5967373288649883 and parameters: {'n_estimators': 790, 'criterion': 'log_loss', 'max_depth': 2, 'min_samples_leaf': 2, 'max_features': 5, 'max_leaf_nodes': 19}. Best is trial 27 with value: 0.6741756532421583.
# [I 2024-02-06 05:36:02,117] Trial 43 finished with value: 0.6558031451163606 and parameters: {'n_estimators': 64, 'criterion': 'log_loss', 'max_depth': 57, 'min_samples_leaf': 2, 'max_features': 12, 'max_leaf_nodes': 18}. Best is trial 27 with value: 0.6741756532421583.
# [I 2024-02-06 05:36:20,719] Trial 41 finished with value: 0.6687742777339739 and parameters: {'n_estimators': 986, 'criterion': 'log_loss', 'max_depth': 57, 'min_samples_leaf': 9, 'max_features': 15, 'max_leaf_nodes': 10}. Best is trial 27 with value: 0.6741756532421583.
# [I 2024-02-06 05:36:50,248] Trial 44 finished with value: 0.6652962771785548 and parameters: {'n_estimators': 953, 'criterion': 'log_loss', 'max_depth': 41, 'min_samples_leaf': 1, 'max_features': 11, 'max_leaf_nodes': 10}. Best is trial 27 with value: 0.6741756532421583.
# [I 2024-02-06 05:37:01,688] Trial 45 finished with value: 0.673327660486185 and parameters: {'n_estimators': 756, 'criterion': 'log_loss', 'max_depth': 43, 'min_samples_leaf': 1, 'max_features': 11, 'max_leaf_nodes': 17}. Best is trial 27 with value: 0.6741756532421583.
# [I 2024-02-06 05:37:30,910] Trial 46 finished with value: 0.6487663457365243 and parameters: {'n_estimators': 753, 'criterion': 'gini', 'max_depth': 25, 'min_samples_leaf': 4, 'max_features': 17, 'max_leaf_nodes': 17}. Best is trial 27 with value: 0.6741756532421583.
# [I 2024-02-06 05:37:34,132] Trial 47 finished with value: 0.6520227030592366 and parameters: {'n_estimators': 556, 'criterion': 'gini', 'max_depth': 25, 'min_samples_leaf': 5, 'max_features': 21, 'max_leaf_nodes': 17}. Best is trial 27 with value: 0.6741756532421583.
# [I 2024-02-06 05:38:02,054] Trial 48 finished with value: 0.665027477390167 and parameters: {'n_estimators': 663, 'criterion': 'entropy', 'max_depth': 45, 'min_samples_leaf': 5, 'max_features': 8, 'max_leaf_nodes': 14}. Best is trial 27 with value: 0.6741756532421583.
# [I 2024-02-06 05:38:06,751] Trial 49 finished with value: 0.6717793937447885 and parameters: {'n_estimators': 671, 'criterion': 'entropy', 'max_depth': 45, 'min_samples_leaf': 3, 'max_features': 12, 'max_leaf_nodes': 14}. Best is trial 27 with value: 0.6741756532421583.

# %%
rf_study.best_params
# Out:
# {'n_estimators': 847,
#  'criterion': 'log_loss',
#  'max_depth': 13,
#  'min_samples_leaf': 1,
#  'max_features': 14,
#  'max_leaf_nodes': 14}

# %%
opt_rf=RandomForestClassifier(n_jobs=-1, random_state=777,
                              **rf_study.best_params)
opt_rf.fit(X_train,y_train)
# Out:
# RandomForestClassifier(criterion='log_loss', max_depth=13, max_features=14,
#                        max_leaf_nodes=14, n_estimators=847, n_jobs=-1,
#                        random_state=777)

# %%
opt_rf_ypred=opt_rf.predict(X_test)
opt_rf_f1=f1_score(y_test,opt_rf_ypred)
opt_rf_f1

# %%
#모델 저장
filename = "rf_f1_66.pkl"
pickle.dump(opt_rf, open( filename, "wb") )

# %%
#잘 저장되었는지 확인
new_model = pickle.load( open( "/content/rf_f1_66.pkl", "rb"))
(new_model.predict(X_test) != opt_xgb.predict(X_test)).sum()

# %% [markdown]
# # LightGBM

# %%
from lightgbm import LGBMClassifier

# %%
def lgbm_objective_1(trail):

    params = {
        "n_estimators" : trail.suggest_int("n_estimators", 5,50),
        "criterion": trail.suggest_categorical("criterion", ["gini", "entropy","log_loss"]),
        "max_depth":trail.suggest_int("max_depth", 1,50),
        "min_samples_leaf":trail.suggest_int("min_samples_leaf", 1,50),
        "max_features": trail.suggest_int("max_features", 1, X_train.shape[1]),
        "max_leaf_nodes":trail.suggest_int("max_leaf_nodes", 1,300)
                                      }

    lgbm_opt = LGBMClassifier( n_jobs=-1, random_state=777,**params )

    lgbm_opt.fit(X_train, y_train)
    scores = cross_val_score( lgbm_opt, X_train, y_train, cv=str_kfold,scoring="f1")

    f1_mean = scores.mean()
    return f1_mean

# %%
lgbm_opt_study=optuna.create_study(direction='maximize')
lgbm_opt_study.optimize(lgbm_objective_1,n_trials=50,n_jobs=-1)

# %%
lgbm_opt_study.best_params

# %%
opt_lgbm=LGBMClassifier(n_jobs=-1, random_state=777,
                               **lgbm_opt_study.best_params)
opt_lgbm.fit(X_train,y_train)

# %%
opt_lgbm_ypred=opt_lgbm.predict(X_test)
opt_lgbm_f1=f1_score(y_test,opt_lgbm_ypred)
opt_lgbm_f1

# %%
filename = "MP_lgbm_73.pkl"
pickle.dump(opt_lgbm, open(filename, "wb"))

# %%
#잘 저장되었는지 확인
new_model = pickle.load( open( "/content/drive/MyDrive/ML/모델/MP_lgbm_73.pkl", "rb"))
(new_model.predict(X_test) != opt_xgb.predict(X_test)).sum()

# %% [markdown]
# # LGBM으로 분석

# %%
#학습
new_model.fit(X_train,y_train)
# Out:
# [LightGBM] [Warning] Unknown parameter: max_features
# [LightGBM] [Warning] Unknown parameter: criterion
# [LightGBM] [Warning] min_data_in_leaf is set with min_child_samples=20, will be overridden by min_samples_leaf=23. Current value: min_data_in_leaf=23
# [LightGBM] [Warning] num_leaves is set=31, max_leaf_nodes=108 will be ignored. Current value: num_leaves=31
# [LightGBM] [Warning] Accuracy may be bad since you didn't explicitly set num_leaves OR 2^max_depth > num_leaves. (num_leaves=31).
# [LightGBM] [Warning] Unknown parameter: max_features
# [LightGBM] [Warning] Unknown parameter: criterion
# [LightGBM] [Warning] min_data_in_leaf is set with min_child_samples=20, will be overridden by min_samples_leaf=23. Current value: min_data_in_leaf=23
# [LightGBM] [Warning] num_leaves is set=31, max_leaf_nodes=108 will be ignored. Current value: num_leaves=31
# [LightGBM] [Warning] Accuracy may be bad since you didn't explicitly set num_leaves OR 2^max_depth > num_leaves. (num_leaves=31).
# [LightGBM] [Info] Number of positive: 288, number of negative: 1081
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000597 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2630
# [LightGBM] [Info] Number of data points in the train set: 1369, number of used features: 24
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.210373 -> initscore=-1.322681
# [LightGBM] [Info] Start training from score -1.322681
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# LGBMClassifier(criterion='log_loss', max_depth=28, max_features=18,
#                max_leaf_nodes=108, min_samples_leaf=23, n_estimators=45,
#                n_jobs=-1, random_state=777)

# %%
#예측
new_model_ypred1=pd.DataFrame(new_model.predict_proba(X_test))
new_model_ypred2=pd.DataFrame(new_model.predict(X_test))
# Out:
# [LightGBM] [Warning] Unknown parameter: max_features
# [LightGBM] [Warning] Unknown parameter: criterion
# [LightGBM] [Warning] min_data_in_leaf is set with min_child_samples=20, will be overridden by min_samples_leaf=23. Current value: min_data_in_leaf=23
# [LightGBM] [Warning] num_leaves is set=31, max_leaf_nodes=108 will be ignored. Current value: num_leaves=31
# [LightGBM] [Warning] Accuracy may be bad since you didn't explicitly set num_leaves OR 2^max_depth > num_leaves. (num_leaves=31).
# [LightGBM] [Warning] Unknown parameter: max_features
# [LightGBM] [Warning] Unknown parameter: criterion
# [LightGBM] [Warning] min_data_in_leaf is set with min_child_samples=20, will be overridden by min_samples_leaf=23. Current value: min_data_in_leaf=23
# [LightGBM] [Warning] num_leaves is set=31, max_leaf_nodes=108 will be ignored. Current value: num_leaves=31
# [LightGBM] [Warning] Accuracy may be bad since you didn't explicitly set num_leaves OR 2^max_depth > num_leaves. (num_leaves=31).

# %%
#Confusion Matrix
from sklearn.metrics import confusion_matrix
cm=confusion_matrix(y_test,new_model_ypred2)

# %%
sns.heatmap(cm, annot=True, cmap='Blues')
plt.show()

# %%
# 특성 중요도 값 확인
importances = new_model.feature_importances_

# 중요도를 기준으로 특성의 순서를 얻기
indices = importances.argsort()[::-1]

# 중요도가 높은 순서대로 특성 이름과 중요도 출력
for i in indices:
  print(f"{X_train.columns[i]} {importances[i]}")
# Out:
# seed 159
# liabilities 133
# employer 132
# Started 124
# totalCapital 115
# mean_Traffic 103
# netProfit 102
# totalAssets 89
# operatingProfit 86
# profit 83
# news 74
# Make_month 50
# tech_cnt 41
# tech_rank 29
# ceo_info 11
# major_IT 4
# Make_year 3
# uni_sky 3
# major_의약 0
# uni_기타 0
# uni_해외 0
# uni_과학기술 0
# major_경영 0
# major_공학 0
# major_사회 0
# major_예체능 0
# major_자연 0
# major_인문 0
# major_교육 0

# %%
#실패사례
new_model.predict(X_test)[57]  #0
# Out:
# [LightGBM] [Warning] Unknown parameter: max_features
# [LightGBM] [Warning] Unknown parameter: criterion
# [LightGBM] [Warning] min_data_in_leaf is set with min_child_samples=20, will be overridden by min_samples_leaf=23. Current value: min_data_in_leaf=23
# [LightGBM] [Warning] num_leaves is set=31, max_leaf_nodes=108 will be ignored. Current value: num_leaves=31
# [LightGBM] [Warning] Accuracy may be bad since you didn't explicitly set num_leaves OR 2^max_depth > num_leaves. (num_leaves=31).
# 0

# %%
new_model.predict_proba(X_test)[57]
# Out:
# [LightGBM] [Warning] Unknown parameter: max_features
# [LightGBM] [Warning] Unknown parameter: criterion
# [LightGBM] [Warning] min_data_in_leaf is set with min_child_samples=20, will be overridden by min_samples_leaf=23. Current value: min_data_in_leaf=23
# [LightGBM] [Warning] num_leaves is set=31, max_leaf_nodes=108 will be ignored. Current value: num_leaves=31
# [LightGBM] [Warning] Accuracy may be bad since you didn't explicitly set num_leaves OR 2^max_depth > num_leaves. (num_leaves=31).
# array([0.99756318, 0.00243682])

# %%
#성공사례
new_model.predict(X_test)[80]  #1
# Out:
# [LightGBM] [Warning] Unknown parameter: max_features
# [LightGBM] [Warning] Unknown parameter: criterion
# [LightGBM] [Warning] min_data_in_leaf is set with min_child_samples=20, will be overridden by min_samples_leaf=23. Current value: min_data_in_leaf=23
# [LightGBM] [Warning] num_leaves is set=31, max_leaf_nodes=108 will be ignored. Current value: num_leaves=31
# [LightGBM] [Warning] Accuracy may be bad since you didn't explicitly set num_leaves OR 2^max_depth > num_leaves. (num_leaves=31).
# 1

# %%
new_model.predict_proba(X_test)[80]
# Out:
# [LightGBM] [Warning] Unknown parameter: max_features
# [LightGBM] [Warning] Unknown parameter: criterion
# [LightGBM] [Warning] min_data_in_leaf is set with min_child_samples=20, will be overridden by min_samples_leaf=23. Current value: min_data_in_leaf=23
# [LightGBM] [Warning] num_leaves is set=31, max_leaf_nodes=108 will be ignored. Current value: num_leaves=31
# [LightGBM] [Warning] Accuracy may be bad since you didn't explicitly set num_leaves OR 2^max_depth > num_leaves. (num_leaves=31).
# array([0.16253614, 0.83746386])
